# %%
import numpy as np
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
var_pd=pd.read_csv('/home/golf/code/AbnormalBDL/output/exp1/test/plots/var_at_epoch5.csv').apply(lambda x:np.sqrt(x))
mean_pd=pd.read_csv('/home/golf/code/AbnormalBDL/output/exp1/test/plots/mean_at_epoch5.csv')

# %%
var_ab=np.array(var_pd[var_pd.labels==1]['var'])
mean_ab=np.array(mean_pd[mean_pd.labels==1]['scores'])
var_n=np.array(var_pd[var_pd.labels==0]['var'])
mean_n=np.array(mean_pd[mean_pd.labels==0]['scores'])

# %%
var_pd.head()
# Out:
#    Unnamed: 0       var  labels
# 0    0.000000  0.014453     0.0
# 1    1.000000  0.014024     0.0
# 2    1.414214  0.008000     0.0
# 3    1.732051  0.009398     0.0
# 4    2.000000  0.004110     0.0

# %%
var=np.array(var_pd['var'])

# %%
abn_mean = mean_pd.loc[mean_pd.labels == 1]['scores']
nrm_mean = mean_pd.loc[mean_pd.labels == 0]['scores']

# %%
sns.distplot(nrm_mean, label=r'Abnormal Score')
sns.distplot(abn_mean, label=r'Normal Score')

# %%
abn_mean = mean_pd.loc[mean_pd.labels == 1]['scores']+var_pd.loc[var_pd.labels == 1]['var']*2
nrm_mean = mean_pd.loc[mean_pd.labels == 0]['scores']+var_pd.loc[var_pd.labels == 0]['var']*2

# %%
sns.distplot(nrm_mean, label=r'Abnormal Score')
sns.distplot(abn_mean, label=r'Normal Score')

# %%
abn_var = var_pd.loc[var_pd.labels == 1]['var']
nrm_var = var_pd.loc[var_pd.labels == 0]['var']

# %%
sns.distplot(nrm_var, label=r'Normal Variance')
sns.distplot(abn_var, label=r'Abnormal Variance')

# %%
mean_pd.head()
# Out:
#    Unnamed: 0    scores  labels
# 0           0  0.193609       0
# 1           1  0.141207       0
# 2           2  0.188494       0
# 3           3  0.190460       0
# 4           4  0.206416       0

# %%
mean=np.array(mean_pd['scores'])

# %%
plt.plot(mean,var)
plt.title('mean and variance')
plt.xlabel('mean')
plt.ylabel('variance')
# Out:
# Text(0, 0.5, 'variance')

# %%
var_ab=np.array(var_pd[var_pd.labels==1]['var'])
mean_ab=np.array(mean_pd[mean_pd.labels==1]['scores'])
var_n=np.array(var_pd[var_pd.labels==0]['var'])
mean_n=np.array(mean_pd[mean_pd.labels==0]['scores'])

# %%
# fig = plt.figure(figsize=(20,30))
plt.scatter(mean_ab,var_ab,label='abnormal')
# plt.scatter(mean_n,var_n,label='normal')
plt.title('mean and variance')
plt.xlabel('mean')
plt.ylabel('variance')
plt.legend(loc='best')

# %%
# fig = plt.figure(figsize=(20,30))
plt.scatter(mean_ab,var_ab*2,label='abnormal')
plt.scatter(mean_n,var_n*2,label='normal')
plt.title('mean and variance')
plt.xlabel('mean')
plt.ylabel('variance')
plt.legend(loc='best')
