# %%
import numpy as np
import sklearn, os
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score

# %%
a_pairs = "/Users/golf/code/baseline_all_digit"
m_pairs ""
m_n = "/Users/golf/Downloads/exp_all_digit"

baseline_result = []
proposed_result = []

# %%
def read_csv_to_auc_mean(path):
    ret = []
    for digit in range(10):
        file_list = glob(os.path.join(path, "digit_%s"%digit, "test","plots","mean*.csv"))
#         print(file_list)
        best_auc = 0
        for file in file_list:
            mean=pd.read_csv(file)
            mean_n=np.array(mean[mean.labels==0]['scores'])
            mean_ab=np.array(mean[mean.labels==1]['scores'])
            means = np.concatenate([mean_n, mean_ab])
            labels = np.concatenate([np.zeros_like(mean_n),np.ones_like(mean_ab)])
            best_auc = max(best_auc, roc_auc_score(labels, means))
        ret.append(best_auc)
    return ret

# %%
def read_csv_to_auc_var(path):
    ret = []
    for digit in range(10):
        file_list = glob(os.path.join(path, "digit_%s"%digit, "test","plots","var*.csv"))
        best_auc = 0
        for file in file_list:
            mean=pd.read_csv(file)
            mean_n=np.array(mean[mean.labels==0]['var'])
            mean_ab=np.array(mean[mean.labels==1]['var'])
            means = np.concatenate([mean_n, mean_ab])
            labels = np.concatenate([np.zeros_like(mean_n),np.ones_like(mean_ab)])
            best_auc = max(best_auc, roc_auc_score(labels, means))
        ret.append(best_auc)
    return ret

# %%
def read_csv_to_auprc_mean(path):
    ret = []
    for digit in range(10):
        file_list = glob(os.path.join(path, "digit_%s"%digit, "test","plots","mean*.csv"))
        best_auc = 0
        for file in file_list:
            mean = pd.read_csv(file)
            mean_n=np.array(mean[mean.labels==0]['scores'])
            mean_ab=np.array(mean[mean.labels==1]['scores'])
            means = np.concatenate([mean_n, mean_ab])
            labels = np.concatenate([np.zeros_like(mean_n),np.ones_like(mean_ab)])
            temp = max(best_auc, average_precision_score(labels, means))
            
            if temp != best_auc:
                print(file)
                best_auc = temp
        ret.append(best_auc)
    return ret

# %%
proposed_result_mean = read_csv_to_auc_mean(proposed)
proposed_result_var = read_csv_to_auc_var(proposed)
baseline_result = read_csv_to_auc_mean(baselines)

# %%
x = list(map(str,list(range(10))))

plt.plot(x, proposed_result_mean, 'ro-', label='proposed method')
# plt.plot(x, proposed_result_var, 'b^--', label='proposed std')
plt.plot(x, baseline_result, 'g+-', label='ganormaly')
plt.ylim(0.4,1)
plt.xlabel('Digit designated as anomalous class')
plt.ylabel('AUROC')
plt.legend()
# plt.title("Perfromance Comparison")
plt.savefig("comparison_auroc.png", dpi=300)

# %%
proposed_result_mean = read_csv_to_auprc_mean(proposed)
baseline_result = read_csv_to_auprc_mean(baselines)
# Out:
# /Users/golf/Downloads/exp_all_digit/digit_0/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_1/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_1/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_1/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_1/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/exp_all_digit/digit_2/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_2/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_2/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch12.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch9.csv
# /Users/golf/Downloads/exp_all_digit/digit_3/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch9.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_4/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/exp_all_digit/digit_5/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_5/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_5/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/exp_all_digit/digit_5/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_5/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_6/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/exp_all_digit/digit_7/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_7/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_7/test/plots/mean_at_epoch9.csv
# /Users/golf/Downloads/exp_all_digit/digit_7/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_7/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch12.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/exp_all_digit/digit_8/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch12.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch13.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/exp_all_digit/digit_9/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_0/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_0/test/plots/mean_at_epoch12.csv
# /Users/golf/Downloads/baseline_all_digit/digit_1/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_1/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_1/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_2/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_2/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/baseline_all_digit/digit_2/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/baseline_all_digit/digit_2/test/plots/mean_at_epoch2.csv
# /Users/golf/Downloads/baseline_all_digit/digit_2/test/plots/mean_at_epoch3.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_3/test/plots/mean_at_epoch2.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_4/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_5/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_5/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/baseline_all_digit/digit_5/test/plots/mean_at_epoch13.csv
# /Users/golf/Downloads/baseline_all_digit/digit_5/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/baseline_all_digit/digit_5/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch14.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch11.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch10.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch8.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch9.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_6/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_7/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_7/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_8/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_8/test/plots/mean_at_epoch0.csv
# /Users/golf/Downloads/baseline_all_digit/digit_8/test/plots/mean_at_epoch3.csv
# /Users/golf/Downloads/baseline_all_digit/digit_9/test/plots/mean_at_epoch1.csv
# /Users/golf/Downloads/baseline_all_digit/digit_9/test/plots/mean_at_epoch0.csv

# %%
x = list(map(str,list(range(10))))

plt.plot(x, proposed_result_mean, 'ro-', label='proposed method')
# plt.plot(x, proposed_result_var, 'b^--', label='proposed std')
plt.plot(x, baseline_result, 'g+-', label='ganormaly')
plt.ylim(0.4,1)
plt.xlabel('Digit designated as anomalous class')
plt.ylabel('AUPRC')
plt.legend()
# plt.title("Perfromance Comparison")
plt.savefig("comparison_auprc.png", dpi=300)
